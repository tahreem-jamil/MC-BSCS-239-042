# %%
print("Hello World")
# Out:
# Hello World

# %%
print(1)
print("Age", 20)
print(3+2)
print(3-2)
print(3*2)
print(10/2)
print(5 % 2)
# Out:
# 1
# Age 20
# 5
# 1
# 6
# 5.0
# 1

# %%
# integer variable
age = 19
print(age)
Name = "Tahreem"
print(Name)
# Out:
# 19
# Tahreem
